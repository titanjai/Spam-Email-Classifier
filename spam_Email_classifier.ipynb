# %% [markdown]
# # Spam Email Classifier using Machine Learning
#
# ## Project Overview
# This project uses TF-IDF and Logistic Regression to classify SMS messages as Spam or Ham.
#
# ## Technologies Used
# - Python
# - Pandas
# - NLTK
# - Scikit-Learn
# - TF-IDF
# - Logistic Regression
#
# ## Model Accuracy
# - Accuracy: 94.26%
#
# ## Features
# - Data Cleaning
# - Text Preprocessing
# - Tokenization
# - Stopword Removal
# - TF-IDF Vectorization
# - Spam/Ham Prediction

# %%
from google.colab import files #dataset load
uploaded=files.upload(

)
# Out:
#      <input type="file" id="files-be9f9b1a-ffe9-4f85-b918-49e22f3ce0d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be9f9b1a-ffe9-4f85-b918-49e22f3ce0d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import string

df = pd.read_csv("spam.csv", encoding="latin1")

df = df[['v1','v2']]
df.columns = ['label','message']

df["label"]=df["label"].map({"ham":0,"spam":1})#label encoding

print(df.head())

print("ORIGINAL:")
print(df['message'].iloc[0])

df['message'] = df['message'].str.lower()#lowercase

print("\nLOWER:")
print(df['message'].iloc[0])

df['message'] = df['message'].apply(
    lambda x: ''.join(char for char in x if char not in string.punctuation)
)#punctuation removal

print("\nNO PUNCTUATION:")
print(df['message'].iloc[0])

tokens = df['message'].iloc[0].split()#tokenization

print("\nTOKENS:")
print(tokens[:10])

print(type(tokens))
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
# ORIGINAL:
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
#
# LOWER:
# go until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...
#
# NO PUNCTUATION:
# go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat
#
# TOKENS:
# ['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'n']
# <class 'list'>

# %%
df["tokens"]=df["message"].apply(lambda x: x.split())
print(df["tokens"].iloc[0])
print(type(df["tokens"].iloc[0]))
# Out:
# ['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'there', 'got', 'amore', 'wat']
# <class 'list'>

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words=set(stopwords.words("english"))
df["tokens"]=df["tokens"].apply(
    lambda x:[word for word in x if word not in stop_words]
)#stopword removal
print(df["tokens"].iloc[0])
# Out:
# ['go', 'jurong', 'point', 'crazy', 'available', 'bugis', 'n', 'great', 'world', 'la', 'e', 'buffet', 'cine', 'got', 'amore', 'wat']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df["clean_message"]=df["tokens"].apply(
    lambda x:" ".join(x)
)
print(df["clean_message"].iloc[0])
# Out:
# go jurong point crazy available bugis n great world la e buffet cine got amore wat

# %%
from sklearn.feature_extraction.text import TfidfVectorizer#TF-IDF
tfidf=TfidfVectorizer()
x=tfidf.fit_transform(df["clean_message"])
print(x.shape)
# Out:
# (5572, 9376)

# %%
from sklearn.model_selection import train_test_split#train test split
y=df["label"]
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (4457, 9376)
# (1115, 9376)

# %%
from sklearn.linear_model import LogisticRegression#model logistic regression
model=LogisticRegression()
model.fit(X_train,Y_train)
print("training completed")
# Out:
# training completed

# %%
from sklearn.metrics import accuracy_score #accuracy metrics
y_pred=model.predict(X_test)
accuracy=accuracy_score(Y_test,y_pred)
print("accuracy",accuracy)
# Out:
# accuracy 0.9426008968609866

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_test,y_pred))
print(classification_report(Y_test,y_pred))
# Out:
# [[961   4]
#  [ 60  90]]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       965
#            1       0.96      0.60      0.74       150
#
#     accuracy                           0.94      1115
#    macro avg       0.95      0.80      0.85      1115
# weighted avg       0.94      0.94      0.94      1115

# %%
message=["Free entry in a weekly competition . Win cash now!"]
message_tfidf=tfidf.transform(message)
prediction=model.predict(message_tfidf)
print(prediction)
# Out:
# [1]

# %%
message1=["hey bro, are you free in this evening for cricket"]
message1_tfidf=tfidf.transform(message1)
prediction1=model.predict(message1_tfidf)
print(prediction1)
# Out:
# [0]
